# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0., 1., 0.1)
plt.plot(p, -1*np.log(p))
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
plt.plot(p, -1*np.log(1-p))
plt.show()
